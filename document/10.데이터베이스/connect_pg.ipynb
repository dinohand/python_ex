# %%
#https://www.bing.com/search?q=postgresql+python&form=ANNTH1&refig=693674a7070e498fba9a2ba04659b91c&pc=U531&adppc=EDGEESS&pqlth=17&assgl=17&sgcn=postgresql+python&sgtpv=UT&smvpcn=0&swbcn=10&sctcn=0&cvid=693674a7070e498fba9a2ba04659b91c&kpratsg=1&hsmssg=0
#pip install psycopg2
# or
# pip install psycopg2-binary

import psycopg2

user_id = 'sqlmanager'
user_pw = 'sqliloveu'
host = '127.0.0.1'
port = '5432'
database = 'work'
schema = 'private'

dsn =  host + ':' + port + '/' + database 



try :
    
   
    conn = psycopg2.connect(host=host, dbname='work',user=user_id, password=user_pw, port=5432)
    
    
    cs = conn.cursor()
    cs.execute(f"select * from {schema}.test")
    rs = cs.fetchall()
    print(rs)
    cs.close()
except Exception as e:
    print('Error:', e)
# Out:
# [('육종곤', {'name': '홍길동', 'age': 30, 'married': False, 'skills': ['JavaScript', 'Python'], 'address': {'city': '서울', 'zipcode': '12345'}})]
