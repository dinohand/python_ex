# %%
import matplotlib.pyplot as plt  # pip install matplotlib


# 한글이 꺠지지 않고 출력되기 위해서는 
plt.rc("font", family="Malgun Gothic")   # Set the font to Malgun Gothic for Korean characters

# plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro-')  # Plotting a simple line graph

# plt.plot([1,2, 4,8], [12,43,25,15],'ro-')  # Plotting a simple line graph

plt.plot([1,2, 4,8] ,'ro-')  # ==> y axis data , x axis datat is auto-generated 0.0, 1.0, 2.0, 3.0   'ro-' => 빨간색 circle 라인

# plt.plot([x 축데이터], [축 데이터],'ro-')  # Plotting a simple line graph


plt.xlabel('X-axis Label')  # Label for the x-axis  
plt.ylabel('Y-axis Label')  # Label for the y-axis
plt.title('라인 그래프')  # Title of the graph   
plt.grid(True)  # Enable grid
plt.legend()
# plt.savefig('simple_line_graph.png')  # Save the graph as a PNG file
plt.show()  # Display the graph

# %%
# xlim, ylim
import matplotlib.pyplot as plt  # pip install matplotlib

# plt.rc("font", family="Malgun Gothic")   # Set the font to Malgun Gothic for Korean characters
# plt.rcParams['axes.unicode_minus'] = False  # Ensure minus sign is displayed correctly

plt.plot([1,2, 4,8] ,'ro-')  # ==> y axis data , x axis datat is auto-generated 0.0, 1.0, 2.0, 3.0   'ro-' => 빨간색 circle 라인


plt.xlabel('X-axis Label')  # Label for the x-axis  
plt.ylabel('Y-axis Label')  # Label for the y-axis
plt.title('Title')  # Title of the graph 
# plt.xlim(0, 5)  # Set x-axis limits
# plt.ylim(0, 10)  # Set y-axis limits
plt.axis([-1, 5, -1, 5])  # Set x and y axis limits [xmin, xmax, ymin, ymax]
# plt.axis('off')
# plt.axis('equal')

plt.show()  # Display the graph

# %%
import matplotlib.pyplot as plt  # pip install matplotlib


# 한글이 꺠지지 않고 출력되기 위해서는 
plt.rc("font", family="Malgun Gothic")   # Set the font to Malgun Gothic for Korean characters

x_data = [1, 2, 3, 4]
y_data = [1, 4, 9, 16]

##### https://matplotlib.org/stable/api/markers_api.html

lstyle = 'dashed'
lwidth = 2.5
m_shape = '>'  # o, *, p, >
m_size = 10


plt.ylabel('Y-axis Label')  # Label for the y-axis
plt.title('라인 그래프')  # Title of the graph   
plt.grid(True)  # Enable grid


# plt.plot(y_data ,'ro-')  # ==> y axis data , x axis datat is auto-generated 0.0, 1.0, 2.0, 3.0
# plt.plot(x_data, y_data, linewidth=lwidth, marker=m_size, markersize=m_size)
# plt.plot(x_data, y_data, marker=m_shape )
plt.plot(x_data, 'b*' , label='xdata')
plt.plot( y_data, 'ro' , label='ydata')


# plt.plot(x_data, y_data ,'ro-') 


# plt.plot([x 축데이터], [축 데이터],'ro-')  # Plotting a simple line graph


plt.xlabel('X-axis Label')  # Label for the x-axis  
# plt.savefig('simple_line_graph.png')  # Save the graph as a PNG file
plt.legend()   # 레전드 보이게함
plt.show()  # Display the graph



# from plotly.validator_cache import ValidatorCache



# for i in range(10):
#     print(i)
#     if i == 5:
#         break

# %%
import matplotlib

for key, value  in matplotlib.markers.MarkerStyle.markers.items():
    print(key, '--' , value)  # Print each marker name
# Out:
# . -- point
# , -- pixel
# o -- circle
# v -- triangle_down
# ^ -- triangle_up
# < -- triangle_left
# > -- triangle_right
# 1 -- tri_down
# 2 -- tri_up
# 3 -- tri_left
# 4 -- tri_right
# 8 -- octagon
# s -- square
# p -- pentagon
# * -- star
# h -- hexagon1
# H -- hexagon2
# + -- plus
# x -- x
# D -- diamond
# d -- thin_diamond
# | -- vline
# _ -- hline
# P -- plus_filled
# X -- x_filled
# 0 -- tickleft
# 1 -- tickright
# 2 -- tickup
# 3 -- tickdown
# 4 -- caretleft
# 5 -- caretright
# 6 -- caretup
# 7 -- caretdown
# 8 -- caretleftbase
# 9 -- caretrightbase
# 10 -- caretupbase
# 11 -- caretdownbase
# None -- nothing
# none -- nothing
#   -- nothing
#  -- nothing

# %%
# Matplotlib 축 범위 지정하기
import matplotlib.pyplot as plt  # pip install matplotlib
import numpy as np
