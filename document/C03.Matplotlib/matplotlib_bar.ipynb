# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(4)
print(x)
years = ['2018', '2019', '2020','']
values = [100, 400, 900, 1200]

plt.bar(x, values)
plt.xticks(x, years)

plt.show()
# Out:
# [0 1 2 3]
