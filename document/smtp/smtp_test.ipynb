# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import os

class MailSender:
    def __init__(self, login :str = '' , password : str = '' , smtp_server :str ='' , smtp_port:int = 100):
        self.__server = smtplib.SMTP(smtp_server, smtp_port)
        self.__server.login(login, password)
        self.__msg = MIMEMultipart('mixed')
        self.__content =''
        self.__subject = ''
        self.__sender = ''
    
        
    # 메일 서버
    @property
    def server(self):
        return self.__server

    @server.setter
    def server(self, smtp_server : str):
        self.__server = smtp_server

    # 메일 제목
    @property
    def subject(self):
        return self.__subject

    @subject.setter
    def subject(self, subject : str = ''):
        self.__subject = subject
        self.msg['Subject'] = self.__subject

    # 발신자
    @property
    def sender(self):
        return self.__sender

    @sender.setter
    def sender(self, sender : str = ''):
        self.__sender = sender
        self.msg['From'] = self.__sender
    
    # 수신자
    @property
    def reciever(self):
        return self.__reciever
    
    @reciever.setter
    def reciever(self, reciever : str = ''):
        self.__reciever = reciever
        self.msg['To'] = self.__reciever
        
    def attach(self):
        if attachment_path:
            attachment = open(attachment_path, "rb")
            part = MIMEBase('application', 'octet-stream')
            part.set_payload((attachment).read())
            encoders.encode_base64(part)
            part.add_header('Content-Disposition', f"attachment; filename= {os.path.basename(attachment_path)}")
            msg.attach(part)
 
    def add_content(sefl, content):
        
        self.email.attach(MIMEText (content, 'html'))
        
        
    def send(send):
        with server.SMTP(smtp_server, port) as server:
            server.sendmail(self.from_email, self.to_email, self.content )
            server.quit()    

    def add_cid(self, cid_name:str, cid_image : bytes):
        cid_data = MIMEImage(cid_image)
        cid_data.add_header('Content-ID', f'<{cid_name}>')
        self.email.attach(cid_data)

# # Example usage
# if __name__ == "__main__":
#     subject = "Daily Report"
#     body = "Please find attached the daily report."
#     to_email = "recipient@example.com"
#     from_email = "your_email@example.com"
#     smtp_server = "smtp.example.com"
#     smtp_port = 587
#     login = "your_email@example.com"
#     password = "your_password"
#     # attachment_path = "/path/to/report.csv"

#     # send_email(subject, body, to_email, from_email, smtp_server, smtp_port, login, password, attachment_path)
#     send_email(subject, body, to_email, from_email, smtp_server, smtp_port, login, password)

# %%
import smtplib, ssl
from email.mime.text import MIMEText

def send_email(subject, body, to_email, from_email, smtp_server, smtp_port, login, password): 
    msg = MIMEText(body, 'html')
    msg['Subject'] = subject
    msg['From'] = from_email
    msg['To'] = to_email


    try:
        # with smtplib.SMTP(smtp_server, smtp_port) as server:

        #     server.starttls()  # Upgrade the connection to a secure encrypted SSL/TLS connection
        #     server.login(login, password)
        #     server.sendmail(from_email, to_email, msg.as_string())
        # print("Email sent successfully!")

        context = ssl.create_default_context()
        with smtplib.SMTP_SSL(smtp_server, smtp_port, context=context) as server:
            server.login(login, password)
            # TODO: Send email here
            server.sendmail(from_email, to_email, subject= subject, msg= body)

    except Exception as e:
        print(f"Failed to send email: {e}")


smtp_server = 'smtp.naver.com'
smtp_port = 465
login = 'yodikodi'
password = '0316kodi'
subject = 'Daily Report'
body = 'Please find attached the daily report.'
to_email = 'excelon@live.co.kr'
from_email = 'yodikodi@naver.com'

send_email(subject=subject, body = body ,from_email=from_email, to_email=to_email, login=login, password=password, smtp_server=smtp_server, smtp_port=smtp_port)
# Out:
# Failed to send email: (535, b'5.7.1 Username and Password not accepted RlAqPuRQSRij7K15GHwhBg - nsmtp')

# %%
import smtplib
from email.mime.text import MIMEText

# 네이버 SMTP 서버 정보
SMTP_SERVER = "smtp.naver.com"
SMTP_PORT = 465


# 이메일 보내기 함수
def send_email():
    try:
        # 이메일 메시지 생성
        body="이것은 Python으로 보낸 테스트 메일입니다."
        msg = MIMEText(body)
        msg['Subject'] = '제목'
        msg['From'] = 'yodikodi@naver.com'
        msg['To'] = 'excelon@live.co.kr'


        # SMTP 서버 연결 및 로그인
        with smtplib.SMTP_SSL(SMTP_SERVER, SMTP_PORT) as server:
            # server.starttls()  # TLS 암호화 시작
            server.login(user='yodikodi', password='!0316Kodi')  # 로그인
            server.sendmail(fro, to_email, msg.as_string())  # 이메일 전송

        print("메일이 성공적으로 전송되었습니다!")
    except Exception as e:
        print(f"메일 전송 중 오류 발생: {e}")

# 함수 호출 예제
send_email()
# Out:
# 메일 전송 중 오류 발생: (535, b'5.7.1 Username and Password not accepted Y4i9EjQZTYCqwLh1c5B4Wg - nsmtp')

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Email configuration
smtp_server = "smtp.naver.com"  # Replace with your SMTP server
port = 465  # SSL port
sender_email = "yodikodi@naver.com"
password = "!0316Kodi"
receiver_email = "excelon@live.co.kr"

# Create the email
subject = "Test Email via SMTP SSL"
body = "This is a test email sent using Python with SMTP over SSL."

message = MIMEMultipart('mix')
message["From"] = sender_email
message["To"] = receiver_email
message["Subject"] = subject
message.attach(MIMEText(body, "plain"))

try:
    # Connect to the SMTP server using SSL
    with smtplib.SMTP_SSL(smtp_server, port) as server:
        server.login('yodikodi@naver.com', password)  # Login to the server
        server.sendmail(sender_email, receiver_email, message.as_string())  # Send the email
        print("Email sent successfully!")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: (535, b'5.7.1 Username and Password not accepted MeChLcItT3KggUWsSqOsbA - nsmtp')
