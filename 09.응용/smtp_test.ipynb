# %%
import smtplib , ssl ## python 기본 라이브러리리
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
# from email.message import EmailMessage
import os


class MailSender:
    
    def __init__(self, 
                 login :str = '' ,
                 password : str = ''  , 
                 smtp_server :str = '' , 
                 smtp_port:int = 465, 
                 subject: str ='', 
                 sender: str ='', 
                 content : str ='', 
                 reciever:str='' , 
                 ssl:bool= False):
        self.__login = login
        self.__password = password
        self.__smtp_server = smtp_server
        self.__smtp_port= smtp_port
        self.__sender  = sender
        self.__reciever = reciever
        self.__ssl = ssl
        self.__subject = subject
        self.__content = content
        self.__msg = MIMEMultipart('mixed')  # important
        
        self.setMsg()

    # 메일 설정을 적용한다
    def setMsg(self):        
        self.__msg['Subject'] = self.__subject
        self.__msg['From'] = self.__sender
        self.__msg['To'] = self.__reciever
        # self.__msg.attach(MIMEText( self.__content , 'html'))

    def attach(self):
        if attachment_path:
            attachment = open(attachment_path, "rb")
            part = MIMEBase('application', 'octet-stream')
            part.set_payload((attachment).read())
            encoders.encode_base64(part)
            part.add_header('Content-Disposition', f"attachment; filename= {os.path.basename(attachment_path)}")
            msg.attach(part)
 
    # def add_content(self, content):
    #     self.email.attach(MIMEText (content, 'html'))

    # def add_cid(self, cid_name:str, cid_image : bytes):
    #     cid_data = MIMEImage(cid_image)
    #     cid_data.add_header('Content-ID', f'<{cid_name}>')
    #     self.email.attach(cid_data)

    def send(self):
        server = smtplib.SMTP_SSL(self.__smtp_server,self.__smtp_port) if ssl else smtplib.SMTP(self.__smtp_server,self.__smtp_port)
        # server.ehlo()
        server.starttls()
        server.sendmail(self.__sender, self.__reciever, self.__msg.as_string() )
        server.quit()    
            


# Example usage
if __name__ == "__main__":
    subject = "Daily Report"
    body = ssl.create_default_context()
    
    #  "Please find attached the daily report."
    
    to_email = "excelon@live.co.kr"
    from_email = "yodikodi@naver.com"
    smtp_server = 'smtp.naver.com'
    smtp_port = 587
    login = "yodikodi"
    password = "6PJ62UUYSXKL"   # 2단계 인증시 어플리캐이션 비밀번호를 설정하여 사용한다다
    
    # attachment_path = "/path/to/report.csv"

    # send_email(subject, body, to_email, from_email, smtp_server, smtp_port, login, password, attachment_path)
    # send_email(subject, body, to_email, from_email, smtp_server, smtp_port, login, password, subject =subject , content = body, sender = from_mail, reciever = to_mail )

    M = MailSender( 
                   login=login, 
                   password=password, 
                   smtp_server = smtp_server, 
                   smtp_port= smtp_port, 
                   subject =subject , 
                   content = body, 
                   sender = from_email, 
                   reciever = to_email,
                   ssl=False
                   )

    M.send()
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# Cell In[17], line 90
#      73 # attachment_path = "/path/to/report.csv"
#      74
#      75 # send_email(subject, body, to_email, from_email, smtp_server, smtp_port, login, password, attachment_path)
#      76 # send_email(subject, body, to_email, from_email, smtp_server, smtp_port, login, password, subject =subject , content = body, sender = from_mail, reciever = to_mail )
#      78 M = MailSender(
#      79                login=login,
#      80                password=password,
#    (...)
#      87                ssl=False
#      88                )
# ---> 90 M.send()
#
# Cell In[17], line 51, in MailSender.send(self)
#      50 def send(self):
# ---> 51     server = smtplib.SMTP_SSL(self.__smtp_server,self.__smtp_port) if ssl else smtplib.SMTP(self.__smtp_server,self.__smtp_port)
#      52     # server.ehlo()
# ...

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.application import MIMEApplication

recipients = ["excelon@live.co.kr"]

message = MIMEMultipart();
message['Subject'] = f'메일 전송 테스트'
message['From'] = "yodikodi@naver.com"
message['To'] = ",".join(recipients)

content = """
    <html>
    <body>
        <h2>{title}</h2>
        <p>메일 전송 테스트입니다</p>
    </body>
    </html>
""".format(
title = '메일.. 받으셨나요..?'
)

mimetext = MIMEText(content,'html')
message.attach(mimetext)

email_id = 'yodikodi'
email_pw = '6PJ62UUYSXKL'

server = smtplib.SMTP('smtp.naver.com',587)
# server.ehlo()
server.starttls()
server.login(email_id,email_pw)
server.sendmail(message['From'],recipients,message.as_string())
server.quit()

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.application import MIMEApplication
import datetime

# recipients = ["excelon@live.co.kr"]

subject =  f'메일 전송 테스트 {datetime.datetime.now()}'

message = MIMEMultipart('mixed') 
message['Subject'] = subject
message['From'] = "yodikodi@naver.com"
# message['To'] = ",".join(recipients)
message['To'] = "jk.youk@kakao.com,excelon@live.co.kr"


content = """
    <html>
    <body>
        <h2>테스트 메일</h2>
        <p>메일 전송 테스트입니다</p>
    </body>
    </html>
"""


mimetext = MIMEText(content,'html')
message.attach(mimetext)

email_id = 'yodikodi'
email_pw = '6PJ62UUYSXKL'
try:
    server = smtplib.SMTP('smtp.naver.com',587)
    # server.ehlo()
    server.starttls()
    server.login(email_id,email_pw)
    server.sendmail(message['From'], message['To'], message.as_string())
    print('Success')
except Exception as e:
    print('Error', e)
finally:
    if server is not None:
     server.quit()
# Out:
# Success
